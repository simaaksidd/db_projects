# %% [markdown]
# #### MongoDB Code Lab

# %%
# %env HOST=mongodb+srv://databases.aucclxi.mongodb.net/sample_weatherdata
# %env USER=SimaakSidd1
# %env PW=REUZ3VuTRVrSpjlE
# Out:
# env: HOST=mongodb+srv://databases.aucclxi.mongodb.net/sample_weatherdata
# env: USER=SimaakSidd1
# env: PW=REUZ3VuTRVrSpjlE

# %%
CONNECT="/usr/bin/mongosh $HOST -u $USER -p $PW --quiet"

# %%
#!{CONNECT}

# %%
# !{CONNECT} --eval "show collections"
# Out:
#  data

# %%
# !{CONNECT} --eval "db.restaurants.findOne()"
# Out:
#  {
#   _id: ObjectId("5eb3d668b31de5d588f4292a"),
#   address: {
#     building: '2780',
#     coord: [ -73.98241999999999, 40.579505 ],
#     street: 'Stillwell Avenue',
#     zipcode: '11224'
#   },
#   borough: 'Brooklyn',
#   cuisine: 'American',
#   grades: [
#     { date: ISODate("2014-06-10T00:00:00.000Z"), grade: 'A', score: 5 },
#     { date: ISODate("2013-06-05T00:00:00.000Z"), grade: 'A', score: 7 },
#     {
#       date: ISODate("2012-04-13T00:00:00.000Z"),
#       grade: 'A',
#       score: 12
#     },
#     {
#       date: ISODate("2011-10-12T00:00:00.000Z"),
#       grade: 'A',
#       score: 12
#     }
#   ],
#   name: 'Riviera Caterer',
#   restaurant_id: '40356018'
# }

# %%
# !{CONNECT} -f /home/jupyter/snippets/mongo_queries.js
# Out:
#  ****************************************************************
# 1) Number of documents in the restaurant collection
# 25359
# ****************************************************************
# 2) Find restaurants with name = Riviera Caterer, sort by cuisine
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f4292a"),
#     address: {
#       building: '2780',
#       coord: [
#         -73.98241999999999,
#         40.579505
#       ],
#       street: 'Stillwell Avenue',
#       zipcode: '11224'
#     },
#     cuisine: 'American',
#     name: 'Riviera Caterer'
#   }
# ]
# ****************************************************************
# 3) Number of restaurants named Riviera Caterer
# 1
# ****************************************************************
# 4) Find restaurants with borough = Brooklyn and cuisine = American
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f4292a"),
#     address: {
#       building: '2780',
#       coord: [
#         -73.98241999999999,
#         40.579505
#       ],
#       street: 'Stillwell Avenue',
#       zipcode: '11224'
#     },
#     cuisine: 'American',
#     name: 'Riviera Caterer'
#   }
# ]
# ****************************************************************
# 5) Find restaurants with address.zipcode = 11209
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f4293b"),
#     address: {
#       building: '6909',
#       coord: [
#         -74.0259567,
#         40.6353674
#       ],
#       street: '3 Avenue',
#       zipcode: '11209'
#     },
#     cuisine: 'Delicatessen',
#     name: 'Nordic Delicacies'
#   }
# ]
# ****************************************************************
# 6) Find restaurants with borough = Brooklyn or cuisine = American
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f4292a"),
#     address: {
#       building: '2780',
#       coord: [
#         -73.98241999999999,
#         40.579505
#       ],
#       street: 'Stillwell Avenue',
#       zipcode: '11224'
#     },
#     cuisine: 'American',
#     name: 'Riviera Caterer'
#   }
# ]
# ****************************************************************
# 7) Find restaurants with borough = Brooklyn and not cuisine = American
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f4292b"),
#     address: {
#       building: '7114',
#       coord: [
#         -73.9068506,
#         40.6199034
#       ],
#       street: 'Avenue U',
#       zipcode: '11234'
#     },
#     cuisine: 'Delicatessen',
#     name: "Wilken'S Fine Food"
#   }
# ]
# ****************************************************************
# 8) Find restaurants with an array element score = 80
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f43383"),
#     grades: [
#       {
#         date: ISODate("2014-10-31T00:00:00.000Z"),
#         grade: 'A',
#         score: 9
#       },
#       {
#         date: ISODate("2014-05-16T00:00:00.000Z"),
#         grade: 'A',
#         score: 11
#       },
#       {
#         date: ISODate("2013-11-19T00:00:00.000Z"),
#         grade: 'A',
#         score: 5
#       },
#       {
#         date: ISODate("2013-03-25T00:00:00.000Z"),
#         grade: 'B',
#         score: 19
#       },
#       {
#         date: ISODate("2012-09-05T00:00:00.000Z"),
#         grade: 'B',
#         score: 26
#       },
#       {
#         date: ISODate("2012-04-10T00:00:00.000Z"),
#         grade: 'C',
#         score: 49
#       },
#       {
#         date: ISODate("2011-11-21T00:00:00.000Z"),
#         grade: 'C',
#         score: 80
#       }
#     ]
#   }
# ]
# ****************************************************************
# 9) Find restaurants with an array element score between 70 and 80
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f42bd0"),
#     grades: [
#       {
#         date: ISODate("2014-10-28T00:00:00.000Z"),
#         grade: 'A',
#         score: 9
#       },
#       {
#         date: ISODate("2014-04-10T00:00:00.000Z"),
#         grade: 'A',
#         score: 12
#       },
#       {
#         date: ISODate("2013-08-08T00:00:00.000Z"),
#         grade: 'C',
#         score: 58
#       },
#       {
#         date: ISODate("2013-02-14T00:00:00.000Z"),
#         grade: 'A',
#         score: 13
#       },
#       {
#         date: ISODate("2012-06-15T00:00:00.000Z"),
#         grade: 'C',
#         score: 71
#       }
#     ]
#   }
# ]
# ****************************************************************
# 10) Find restaurants with pizza in manhattan not dominos
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f432f5"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '10Th Avenue Pizza & Cafe'
#   },
#   {
#     _id: ObjectId("5eb3d668b31de5d588f44a56"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f4548e"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f45557"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f455d2"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f4565b"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f45697"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f459e2"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f470c2"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f47cbb"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f467db"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '44Th Street Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f485f2"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '5 Star Cheese Steak And Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f4595a"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '99 Cent Express Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f459b5"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '99 Cent Fresh Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f474fd"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '99 Cent Fresh Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f47556"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '99 Cent Fresh Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f47594"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '99 Cent Fresh Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f4812b"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '99 Cent Fresh Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f474ee"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '99 Cent Fresh Pizza Villa Cafe'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f46d37"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '99 Cent Pizza'
#   }
# ]
# Type "it" for more
# ****************************************************************
# 11) Find amount of restaurants with pizza in manhattan not dominos
# 321

# %% [markdown]
# #### Prompt 1: Find the restaurants whose borough = Manhattan, whose cuisine = Pizza, and whose name is NOT Domino'S Pizza. Return their borough, cuisine, and name. Sort the resulting documents by name. Limit the number of results to 5.

# %%
# !{CONNECT} -f /home/jupyter/snippets/mongo_queries.js
# Out:
#  ****************************************************************
# 1) Number of documents in the restaurant collection
# 25359
# ****************************************************************
# 2) Find restaurants with name = Riviera Caterer, sort by cuisine
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f4292a"),
#     address: {
#       building: '2780',
#       coord: [
#         -73.98241999999999,
#         40.579505
#       ],
#       street: 'Stillwell Avenue',
#       zipcode: '11224'
#     },
#     cuisine: 'American',
#     name: 'Riviera Caterer'
#   }
# ]
# ****************************************************************
# 3) Number of restaurants named Riviera Caterer
# 1
# ****************************************************************
# 4) Find restaurants with borough = Brooklyn and cuisine = American
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f4292a"),
#     address: {
#       building: '2780',
#       coord: [
#         -73.98241999999999,
#         40.579505
#       ],
#       street: 'Stillwell Avenue',
#       zipcode: '11224'
#     },
#     cuisine: 'American',
#     name: 'Riviera Caterer'
#   }
# ]
# ****************************************************************
# 5) Find restaurants with address.zipcode = 11209
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f4293b"),
#     address: {
#       building: '6909',
#       coord: [
#         -74.0259567,
#         40.6353674
#       ],
#       street: '3 Avenue',
#       zipcode: '11209'
#     },
#     cuisine: 'Delicatessen',
#     name: 'Nordic Delicacies'
#   }
# ]
# ****************************************************************
# 6) Find restaurants with borough = Brooklyn or cuisine = American
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f4292a"),
#     address: {
#       building: '2780',
#       coord: [
#         -73.98241999999999,
#         40.579505
#       ],
#       street: 'Stillwell Avenue',
#       zipcode: '11224'
#     },
#     cuisine: 'American',
#     name: 'Riviera Caterer'
#   }
# ]
# ****************************************************************
# 7) Find restaurants with borough = Brooklyn and not cuisine = American
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f4292b"),
#     address: {
#       building: '7114',
#       coord: [
#         -73.9068506,
#         40.6199034
#       ],
#       street: 'Avenue U',
#       zipcode: '11234'
#     },
#     cuisine: 'Delicatessen',
#     name: "Wilken'S Fine Food"
#   }
# ]
# ****************************************************************
# 8) Find restaurants with an array element score = 80
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f43383"),
#     grades: [
#       {
#         date: ISODate("2014-10-31T00:00:00.000Z"),
#         grade: 'A',
#         score: 9
#       },
#       {
#         date: ISODate("2014-05-16T00:00:00.000Z"),
#         grade: 'A',
#         score: 11
#       },
#       {
#         date: ISODate("2013-11-19T00:00:00.000Z"),
#         grade: 'A',
#         score: 5
#       },
#       {
#         date: ISODate("2013-03-25T00:00:00.000Z"),
#         grade: 'B',
#         score: 19
#       },
#       {
#         date: ISODate("2012-09-05T00:00:00.000Z"),
#         grade: 'B',
#         score: 26
#       },
#       {
#         date: ISODate("2012-04-10T00:00:00.000Z"),
#         grade: 'C',
#         score: 49
#       },
#       {
#         date: ISODate("2011-11-21T00:00:00.000Z"),
#         grade: 'C',
#         score: 80
#       }
#     ]
#   }
# ]
# ****************************************************************
# 9) Find restaurants with an array element score between 70 and 80
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f42bd0"),
#     grades: [
#       {
#         date: ISODate("2014-10-28T00:00:00.000Z"),
#         grade: 'A',
#         score: 9
#       },
#       {
#         date: ISODate("2014-04-10T00:00:00.000Z"),
#         grade: 'A',
#         score: 12
#       },
#       {
#         date: ISODate("2013-08-08T00:00:00.000Z"),
#         grade: 'C',
#         score: 58
#       },
#       {
#         date: ISODate("2013-02-14T00:00:00.000Z"),
#         grade: 'A',
#         score: 13
#       },
#       {
#         date: ISODate("2012-06-15T00:00:00.000Z"),
#         grade: 'C',
#         score: 71
#       }
#     ]
#   }
# ]
# ****************************************************************
# 10) Find restaurants with pizza in manhattan not dominos
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f432f5"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '10Th Avenue Pizza & Cafe'
#   },
#   {
#     _id: ObjectId("5eb3d668b31de5d588f44a56"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f4548e"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f45557"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f455d2"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f4565b"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f45697"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f459e2"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f470c2"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f47cbb"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f467db"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '44Th Street Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f485f2"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '5 Star Cheese Steak And Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f4595a"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '99 Cent Express Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f459b5"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '99 Cent Fresh Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f474fd"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '99 Cent Fresh Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f47556"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '99 Cent Fresh Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f47594"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '99 Cent Fresh Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f4812b"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '99 Cent Fresh Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f474ee"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '99 Cent Fresh Pizza Villa Cafe'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f46d37"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '99 Cent Pizza'
#   }
# ]
# Type "it" for more
# ****************************************************************
# 11) Find amount of restaurants with pizza in manhattan not dominos
# 321

# %% [markdown]
# #### Prompt 2: Find the number of restaurants whose borough = Manhattan, whose cuisine = Pizza, and whose name is NOT Domino'S Pizza.

# %%
# !{CONNECT} -f /home/jupyter/snippets/mongo_queries.js
# Out:
#  SyntaxError: Missing semicolon. (47:50)
#
#   45 |
#   46 |
# > 47 | airTemperature:{$elemMatch: {value: {$gt: -10, $lt: 0}}}
#      |                                                   ^

# %% [markdown]
# #### Begin Project 6 Work

# %%
# !{CONNECT} -f /home/jupyter/project/project6_queries.js
# Out:
#  ****************************************************************
# 1) logical AND and range query and filter on embedded field that is one levels deep and sort
# [
#   {
#     _id: ObjectId("5553a998e4b02cf7151190b8"),
#     st: 'x+47600-047900',
#     callLetters: 'VCSZ'
#   },
#   {
#     _id: ObjectId("5553a998e4b02cf715119e02"),
#     st: 'x+47600-047900',
#     callLetters: 'VCSZ'
#   }
# ]
# ****************************************************************
# 2) logical AND and range query and filter on embedded field that is two levels deep
# [
#   {
#     st: 'x+47600-047900',
#     callLetters: 'VCSZ',
#     dataSource: '4',
#     wind: {
#       direction: {
#         angle: 999,
#         quality: '9'
#       },
#       type: '9',
#       speed: {
#         rate: 999.9,
#         quality: '9'
#       }
#     }
#   }
# ]
# ****************************************************************
# 3) Embedded object in array matches x and sort
# [
#   {
#     _id: ObjectId("5553a998e4b02cf7151195fa"),
#     st: 'x+00000+078300',
#     presentWeatherObservationManual: [
#       {
#         condition: '01',
#         quality: '1'
#       }
#     ]
#   }
# ]
# ****************************************************************
# 4) Element in array matches x and Logical OR
# [
#   {
#     _id: ObjectId("5553a998e4b02cf7151190b8"),
#     st: 'x+47600-047900',
#     sections: [
#       'AG1'
#     ]
#   }
# ]
# ****************************************************************
# 5) Embedded object in array matches x and filter on embedded field that is two levels deep
# [
#   {
#     _id: ObjectId("5553a998e4b02cf7151190be"),
#     st: 'x+79800-172000',
#     pastWeatherObservationManual: [
#       {
#         atmosphericCondition: {
#           value: '7',
#           quality: '1'
#         },
#         period: {
#           value: 3,
#           quality: '1'
#         }
#       }
#     ]
#   }
# ]
# ****************************************************************
# 6) logical OR and sort and filter of embedded field that is one level deep
# [
#   {
#     _id: ObjectId("5553a999e4b02cf71511e23f"),
#     st: 'x-75300+006400',
#     airTemperature: {
#       value: -77,
#       quality: '1'
#     },
#     dewPoint: {
#       value: 999.9,
#       quality: '9'
#     }
#   },
#   {
#     _id: ObjectId("5553a999e4b02cf71511de67"),
#     st: 'x+85500-122800',
#     airTemperature: {
#       value: -32.3,
#       quality: '1'
#     },
#     dewPoint: {
#       value: 999.9,
#       quality: '9'
#     }
#   },
#   {
#     _id: ObjectId("5553a999e4b02cf71511bf32"),
#     st: 'x+15500+041700',
#     airTemperature: {
#       value: -30,
#       quality: '1'
#     },
#     dewPoint: {
#       value: 999.9,
#       quality: '9'
#     }
#   }
# ]
# ****************************************************************
# 7) Element in array matches x and sort
# [
#   {
#     _id: ObjectId("5553a998e4b02cf7151195fa"),
#     st: 'x+00000+078300',
#     sections: [
#       'AG1',
#       'AY1',
#       'GF1',
#       'MD1',
#       'MW1',
#       'SA1',
#       'UA1'
#     ]
#   },
#   {
#     _id: ObjectId("5553a999e4b02cf71511ba90"),
#     st: 'x+00000+085000',
#     sections: [
#       'AG1',
#       'AY1',
#       'GF1',
#       'MD1',
#       'MW1',
#       'SA1',
#       'UA1',
#       'UG1'
#     ]
#   },
#   {
#     _id: ObjectId("5553a999e4b02cf71511c131"),
#     st: 'x+00000+086100',
#     sections: [
#       'AA1',
#       'AG1',
#       'AY1',
#       'GF1',
#       'MD1',
#       'MW1',
#       'SA1',
#       'UA1',
#       'UG1'
#     ]
#   }
# ]
# ****************************************************************
# 8) logical AND and sort
# [
#   {
#     _id: ObjectId("5553a998e4b02cf7151190be"),
#     st: 'x+79800-172000',
#     callLetters: 'EMIO',
#     qualityControlProcess: 'V020'
#   },
#   {
#     _id: ObjectId("5553a998e4b02cf7151198f1"),
#     st: 'x+79800-172000',
#     callLetters: 'EMIO',
#     qualityControlProcess: 'V020'
#   },
#   {
#     _id: ObjectId("5553a998e4b02cf715119b58"),
#     st: 'x+79900-171800',
#     callLetters: 'EMIO',
#     qualityControlProcess: 'V020'
#   }
# ]
# ****************************************************************
# 9) range query and sort
# [
#   {
#     _id: ObjectId("5553a999e4b02cf71511b990"),
#     st: 'x+79900-171800',
#     dewPoint: {
#       value: -34.8,
#       quality: '1'
#     }
#   },
#   {
#     _id: ObjectId("5553a99ae4b02cf715120b03"),
#     st: 'x+79900-171800',
#     dewPoint: {
#       value: -34.6,
#       quality: '1'
#     }
#   },
#   {
#     _id: ObjectId("5553a999e4b02cf71511e3f4"),
#     st: 'x+85500-122800',
#     dewPoint: {
#       value: -34.3,
#       quality: '1'
#     }
#   }
# ]
# ****************************************************************
# 10) logical AND and sort
# [
#   {
#     _id: ObjectId("5553a999e4b02cf71511c139"),
#     st: 'x+00000+000000',
#     elevation: 9999,
#     dataSource: '4'
#   },
#   {
#     _id: ObjectId("5553a998e4b02cf715119ca0"),
#     st: 'x+00000+000000',
#     elevation: 9999,
#     dataSource: '4'
#   },
#   {
#     _id: ObjectId("5553a998e4b02cf715119aa4"),
#     st: 'x+00000+000000',
#     elevation: 9999,
#     dataSource: '4'
#   }
# ]

# %% [markdown]
# #### begin extra credit work

# %%
# !{CONNECT} -f /home/jupyter/project/exam1_extra_credit.js
# Out:
#  ****************************************************************
# 1) insertOne
# {
#   acknowledged: true,
#   insertedId: ObjectId("653b074d9f9927c46ad0604b")
# }
# ****************************************************************
# 2) insertMany
# {
#   acknowledged: true,
#   insertedIds: {
#     '0': ObjectId("653b074d9f9927c46ad0604c"),
#     '1': ObjectId("653b074d9f9927c46ad0604d")
#   }
# }
# ****************************************************************
# 3) insertMany
# {
#   acknowledged: true,
#   insertedIds: {
#     '0': ObjectId("653b074d9f9927c46ad0604e"),
#     '1': ObjectId("653b074d9f9927c46ad0604f")
#   }
# }
# ****************************************************************
# 4) updateOne
# {
#   acknowledged: true,
#   insertedId: null,
#   matchedCount: 1,
#   modifiedCount: 1,
#   upsertedCount: 0
# }
# ****************************************************************
# 5) updateOne and $push
# {
#   acknowledged: true,
#   insertedId: null,
#   matchedCount: 1,
#   modifiedCount: 1,
#   upsertedCount: 0
# }
# ****************************************************************
# 6) updateMany
# {
#   acknowledged: true,
#   insertedId: null,
#   matchedCount: 1,
#   modifiedCount: 1,
#   upsertedCount: 0
# }
# ****************************************************************
# 7) updateMany
# {
#   acknowledged: true,
#   insertedId: null,
#   matchedCount: 20,
#   modifiedCount: 20,
#   upsertedCount: 0
# }
# ****************************************************************
# 8) deleteOne
# {
#   acknowledged: true,
#   deletedCount: 1
# }
# ****************************************************************
# 9) deleteMany
# {
#   acknowledged: true,
#   deletedCount: 1
# }
# ****************************************************************
# 10) deleteMany
# {
#   acknowledged: true,
#   deletedCount: 1
# }
